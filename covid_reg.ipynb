# %%
import pandas as pd 
import numpy as np
from pycaret.regression import *

# %%
cols_list = ['location_id', 'date', 'inf_mean', 'seir_cumulative_mean', 'inf_cuml_mean', 'seir_daily_mean', 'cumulative_deaths', 'daily_deaths', 'cumulative_hospitalizations', 'daily_infections', 'testing_mean', 'pneumonia_mean', 'mask_use_mean', 'cumulative_all_vaccinated', 'cumulative_all_fully_vaccinated', 'cumulative_all_effectively_vaccinated', 'hospital_beds_mean', 'icu_beds_mean', 'admis_mean', 'all_bed_capacity', 'icu_bed_capacity', 'infection_fatality', 'infection_detection', 'infection_hospitalization']
cov_worse = pd.read_csv(r'C:\Users\steph\OneDrive\Documents\GitHub\The COVID project\The-COVID-project\Data\healthdata_org_data\worse_2021.csv', usecols=cols_list, parse_dates=['date'])

# %%
cov_worse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162350 entries, 0 to 162349
# Data columns (total 24 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   location_id                            162350 non-null  int64
#  1   date                                   162350 non-null  datetime64[ns]
#  2   inf_mean                               162350 non-null  float64
#  3   seir_cumulative_mean                   162350 non-null  float64
#  4   inf_cuml_mean                          162350 non-null  float64
#  5   seir_daily_mean                        162350 non-null  float64
#  6   cumulative_deaths                      115196 non-null  float64
#  7   daily_deaths                           115196 non-null  float64
#  8   cumulative_hospitalizations            37193 non-null   float64
#  9   daily_infections                       115543 non-null  float64
# ...

# %%
exp_reg = setup(cov_worse, target='daily_deaths')
# Out:
# <style  type="text/css" >
# #T_0c5c0_row3_col1,#T_0c5c0_row42_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_0c5c0_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0c5c0_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0c5c0_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_0c5c0_row0_col1" class="data row0 col1" >5219</td>
#             </tr>
#             <tr>
#                         <th id="T_0c5c0_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_0c5c0_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_0c5c0_row1_col1" class="data row1 col1" >daily_deaths</td>
#             </tr>
# ...

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_a7393_ th {
#           text-align: left;
# ...

# %%
etr = create_model('et')
# Out:
# <style  type="text/css" >
# #T_beef3_row10_col0,#T_beef3_row10_col1,#T_beef3_row10_col2,#T_beef3_row10_col3,#T_beef3_row10_col4,#T_beef3_row10_col5{
#             background:  yellow;
#         }</style><table id="T_beef3_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_beef3_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_beef3_row0_col0" class="data row0 col0" >17.4167</td>
#                         <td id="T_beef3_row0_col1" class="data row0 col1" >7256.3945</td>
# ...

# %%
plot_model(etr)

# %%
plot_model(etr, 'learning')

# %%
plot_model(etr, 'feature')

# %%
interpret_model(etr)
